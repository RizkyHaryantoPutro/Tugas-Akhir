# %% [markdown]
# <a href="https://colab.research.google.com/github/RizkyHaryantoPutro/Tugas-Akhir/blob/main/Tugas%20Akhir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROSES SCRAPING**

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
#Scrape desired number of review
from google_play_scraper import Sort, reviews
result, continuation_token = reviews(
    'com.gojek.gopay',
    lang = 'id',
    country = 'id',
    sort = Sort.MOST_RELEVANT,
    count = 1000,
    filter_score_with = None
)

# %%
data0012 = pd.DataFrame(np.array(result),columns=['review'])
data0012 = data0012.join(pd.DataFrame(data0012.pop('review').tolist()))

#Menampilkan data teratas
data0012.head()
# Out:
#                                reviewId         userName  \
# 0  8ee9e342-fae7-444b-9b88-47f777241837       Dery Basah
# 1  db8d3d4e-c543-46f7-b8f3-57ffc698e65c  Fadillah Rahman
# 2  c6884c36-252c-49f9-b5ad-5585f5ce6b45   Astuti Ndruzeg
# 3  19273dbc-eb8c-4ef7-9bbc-f619d20dd866          Deja Vu
# 4  a45be0ff-f06f-4da8-ba71-8f6374679a33    senia rachman
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Padahal gak pernah telat untuk pembayaran,tanp...      1             27
# 1  Kesannya maksa bgt Marketing lu ajarin, bukan ...      1             44
# ...

# %%
data0012.to_csv("Data1.csv", index = False)

# %%
len(data0012.index)
# Out:
# 1000

# %%
data0012[['userName','score','at','content']].head()
# Out:
#           userName  score                  at  \
# 0       Dery Basah      1 2025-01-13 12:17:50
# 1  Fadillah Rahman      1 2025-01-13 17:54:58
# 2   Astuti Ndruzeg      2 2025-01-15 06:23:11
# 3          Deja Vu      5 2024-11-24 23:14:56
# 4    senia rachman      2 2025-01-13 02:40:10
#
#                                              content
# 0  Padahal gak pernah telat untuk pembayaran,tanp...
# 1  Kesannya maksa bgt Marketing lu ajarin, bukan ...
# 2  Saya udah coba izinkan aplikasih masih saja te...
# 3  Super Apps yg sdh menjadi gateway pembayaran2 ...
# 4  Saya sering gunakan gopay untuk transaksi top ...

# %%
data0012_new = data0012[['userName','score','at','content']]
data0012_sorted = data0012_new.sort_values(by='at', ascending=False) #sort by news
data0012_sorted.head()
# Out:
#             userName  score                  at  \
# 56   Chandra Hombing      5 2025-01-15 16:04:45
# 64     ardah saputra      5 2025-01-15 14:57:36
# 342        Suar Dana      1 2025-01-15 10:45:53
# 346     Dedek Arpani      5 2025-01-15 10:25:32
# 243  Aii Nurhasanahh      1 2025-01-15 10:09:17
#
#                                                content
# 56   Sangat puas saya pada aflikasi gopay tercinta,...
# 64   Alhmdllah udh 2thn ini sya gunain gopay blm ad...
# 342  Udah pake pasword malah minta scan wajah, udah...
# 346  buat makin banyk promo min kalo bisa untung ad...
# 243  Hello sekelas go pay peringatan jatuh tempo ny...

# %%
data0012_scrape = data0012_sorted[['userName','score','at','content']] #get username, rating, date-time

# %%
data0012_scrape.head()
# Out:
#             userName  score                  at  \
# 56   Chandra Hombing      5 2025-01-15 16:04:45
# 64     ardah saputra      5 2025-01-15 14:57:36
# 342        Suar Dana      1 2025-01-15 10:45:53
# 346     Dedek Arpani      5 2025-01-15 10:25:32
# 243  Aii Nurhasanahh      1 2025-01-15 10:09:17
#
#                                                content
# 56   Sangat puas saya pada aflikasi gopay tercinta,...
# 64   Alhmdllah udh 2thn ini sya gunain gopay blm ad...
# 342  Udah pake pasword malah minta scan wajah, udah...
# 346  buat makin banyk promo min kalo bisa untung ad...
# 243  Hello sekelas go pay peringatan jatuh tempo ny...

# %%
data0012_scrape.to_csv("GoPay-Data.csv", index = False)

# %% [markdown]
# **PROSES** **FILTER**

# %%
# !pip install sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install vaderSentiment
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.0 MB/s eta 0:00:00
# ...

# %%
#library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import string
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df0012 = pd.read_csv('GoPay-Data.csv')
df0012.head(5)
# Out:
#           userName  score                   at  \
# 0  Chandra Hombing      5  2025-01-15 16:04:45
# 1    ardah saputra      5  2025-01-15 14:57:36
# 2        Suar Dana      1  2025-01-15 10:45:53
# 3     Dedek Arpani      5  2025-01-15 10:25:32
# 4  Aii Nurhasanahh      1  2025-01-15 10:09:17
#
#                                              content
# 0  Sangat puas saya pada aflikasi gopay tercinta,...
# 1  Alhmdllah udh 2thn ini sya gunain gopay blm ad...
# 2  Udah pake pasword malah minta scan wajah, udah...
# 3  buat makin banyk promo min kalo bisa untung ad...
# 4  Hello sekelas go pay peringatan jatuh tempo ny...

# %%
df0012.shape
# Out:
# (1000, 4)

# %%
#Penambahan Variabel 'LABEL'
sentiment = []
for index, row in df0012.iterrows():
  if row['score'] > 3:
    sentiment.append ('Positif')
  else :
    sentiment.append ('Negativ')

df0012['sentiment'] = sentiment
df0012.head()
# Out:
#           userName  score                   at  \
# 0  Chandra Hombing      5  2025-01-15 16:04:45
# 1    ardah saputra      5  2025-01-15 14:57:36
# 2        Suar Dana      1  2025-01-15 10:45:53
# 3     Dedek Arpani      5  2025-01-15 10:25:32
# 4  Aii Nurhasanahh      1  2025-01-15 10:09:17
#
#                                              content sentiment
# 0  Sangat puas saya pada aflikasi gopay tercinta,...   Positif
# 1  Alhmdllah udh 2thn ini sya gunain gopay blm ad...   Positif
# 2  Udah pake pasword malah minta scan wajah, udah...   Negativ
# 3  buat makin banyk promo min kalo bisa untung ad...   Positif
# 4  Hello sekelas go pay peringatan jatuh tempo ny...   Negativ

# %%
df0012.shape
# Out:
# (1000, 5)

# %%
#menghilangkan variabel yang tidak digunakan
df0012_data = df0012.copy()
df0012_data = df0012.drop(columns = ['userName','score','at'])
df0012_data.head()
# Out:
#                                              content sentiment
# 0  Sangat puas saya pada aflikasi gopay tercinta,...   Positif
# 1  Alhmdllah udh 2thn ini sya gunain gopay blm ad...   Positif
# 2  Udah pake pasword malah minta scan wajah, udah...   Negativ
# 3  buat makin banyk promo min kalo bisa untung ad...   Positif
# 4  Hello sekelas go pay peringatan jatuh tempo ny...   Negativ

# %%
df0012_data.to_csv("GoPay-TESTING-LABEL.csv", index = False)

# %%
df0012_data.shape
# Out:
# (1000, 2)

# %%
nltk.download('punkt')
nltk.download('stopword')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Error loading stopword: Package 'stopword' not found in
# [nltk_data]     index
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# **TOKENIZING**

# %%
df0012_fix = pd.read_csv('GoPay-TESTING-LABEL.csv')

# %%
df0012_fix.content
# Out:
# 0      Sangat puas saya pada aflikasi gopay tercinta,...
# 1      Alhmdllah udh 2thn ini sya gunain gopay blm ad...
# 2      Udah pake pasword malah minta scan wajah, udah...
# 3      buat makin banyk promo min kalo bisa untung ad...
# 4      Hello sekelas go pay peringatan jatuh tempo ny...
#                              ...
# 995    Paling suka sama desainnya. Simpel, bersih, je...
# 996    Kalau Pakai gopay later cukup membantu tiap bu...
# 997    Saya undang teman beberapa orang Buat download...
# 998    Memang aku akui kalau apk nih bagus dari segi ...
# 999    Sangat praktis,lengkap,transaksi cepat secepat...
# Name: content, Length: 1000, dtype: object

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
x = df0012_fix.iloc[0]
print(nltk.word_tokenize(x['content']))
# Out:
# ['Sangat', 'puas', 'saya', 'pada', 'aflikasi', 'gopay', 'tercinta', ',', ',', ',', 'jadikan', 'kenyamanan', 'pengguna', 'di', 'bintang', '1000', 'lh', ',', ',kalau', 'ada', 'banyak', 'bintang', 'reting', 'ulasan', ',', 'pasti', 'saya', 'kasih', 'banyak', 'banyak', ',', 'karena', 'saya', 'sangat', 'puas', 'telah', 'menggunakan', 'aflikasi', 'GOPAY', 'tercinta', ',', ',']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
x = df0012_fix.iloc[0]
print(word_tokenize(x['content']))
# Out:
# ['Sangat', 'puas', 'saya', 'pada', 'aflikasi', 'gopay', 'tercinta', ',', ',', ',', 'jadikan', 'kenyamanan', 'pengguna', 'di', 'bintang', '1000', 'lh', ',', ',kalau', 'ada', 'banyak', 'bintang', 'reting', 'ulasan', ',', 'pasti', 'saya', 'kasih', 'banyak', 'banyak', ',', 'karena', 'saya', 'sangat', 'puas', 'telah', 'menggunakan', 'aflikasi', 'GOPAY', 'tercinta', ',', ',']

# %%
  def identify_tokens(row) :
    text = row['content']
    tokens = nltk.word_tokenize(text)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

  df0012_fix['content'] = df0012_fix.apply(identify_tokens, axis=1)
  df0012_fix.content
# Out:
# 0      [Sangat, puas, saya, pada, aflikasi, gopay, te...
# 1      [Alhmdllah, udh, ini, sya, gunain, gopay, blm,...
# 2      [Udah, pake, pasword, malah, minta, scan, waja...
# 3      [buat, makin, banyk, promo, min, kalo, bisa, u...
# 4      [Hello, sekelas, go, pay, peringatan, jatuh, t...
#                              ...
# 995    [Paling, suka, sama, desainnya, Simpel, bersih...
# 996    [Kalau, Pakai, gopay, later, cukup, membantu, ...
# 997    [Saya, undang, teman, beberapa, orang, Buat, d...
# 998    [Memang, aku, akui, kalau, apk, nih, bagus, da...
# 999    [Sangat, praktis, lengkap, transaksi, cepat, s...
# Name: content, Length: 1000, dtype: object
